# %%
import pandas as pd

# %%
df = pd.read_csv("../../lindas/data/csv/disease_reports_mock_data_.csv")

# %%
df.head().T
# Out:
#                                                                         0  \
# id                                                                      1
# source                                                      gefluegelnews
# title                   100.000 Legehennen wegen Newcastle-Krankheit g...
# url                     https://www.gefluegelnews.de/article/100000-le...
# teaser                  Outbreak of Newcastle disease in a large comme...
# body                    # 100.000 Legehennen wegen Newcastle-Krankheit...
# report_date                                                    2026-03-03
# admin_level_1                                                     Bavaria
# admin_level_2                                                      Erding
# admin_level_3                                                         NaN
# relevance_score                                                       6.0
# relevance_score_string                                               high
# ...

# %%
df.shape
# Out:
# (1085, 15)

# %%
df.source.value_counts()
# Out:
# source
# gefluegelnews    983
# padi_web         102
# Name: count, dtype: int64

# %%
df.admin_level_3.value_counts()
# Out:
# admin_level_3
# Garrel          7
# Putten          5
# Gangkofen       4
# Wietmarschen    3
# Montenegro      3
#                ..
# Parrega         1
# Loo             1
# Süptitz         1
# Finkenthal      1
# Kukua           1
# Name: count, Length: 134, dtype: int64

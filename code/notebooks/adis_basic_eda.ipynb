# %% [markdown]
# # ADIS Outbreaks Basic EDA
#
# Self-contained first-pass EDA for HPAI records in `data/structured/adis/adis-outbreaks-20260519.csv`. This notebook follows the same structure as the WAHIS and EMPRES-i EDA notebooks while keeping ADIS-specific outbreak burden, diagnostic, status, and administrative fields.

# %% [markdown]
# ## Setup
#
# Shared plotting, display, and helper functions used throughout the notebook.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

plt.style.use("ggplot")

params = {
    "text.color": (0.25, 0.25, 0.25),
    "figure.figsize": [16, 9],
}

plt.rcParams.update(params)

# Get colors from default theme.
DEFAULT_COLORS = plt.rcParams["axes.prop_cycle"].by_key()["color"]

import seaborn as sns
# sns.set()


from pathlib import Path

import pandas as pd


pd.options.display.max_columns = 120
pd.options.mode.chained_assignment = None
pd.options.display.max_rows = 500
pd.options.display.max_seq_items = 500


NA_VALUES = ["NaN", "nan", "", ";"]


def find_data_path(*candidates: str) -> Path:
    paths = [Path(candidate) for candidate in candidates]
    path = next((candidate for candidate in paths if candidate.exists()), None)
    if path is None:
        tried = "\n".join(str(candidate) for candidate in paths)
        raise FileNotFoundError(f"Could not find source CSV. Tried:\n{tried}")
    return path


def schema_summary(data: pd.DataFrame) -> pd.DataFrame:
    return pd.DataFrame(
        {
            "dtype": data.dtypes.astype(str),
            "missing": data.isna().sum(),
            "missing_pct": data.isna().mean().mul(100).round(1),
            "n_unique": data.nunique(dropna=True),
        }
    ).sort_values(["missing_pct", "n_unique"], ascending=[False, False])


def top_counts(data: pd.DataFrame, column: str, n: int = 15) -> pd.DataFrame:
    return (
        data[column]
        .fillna("Missing")
        .value_counts(dropna=False)
        .head(n)
        .rename_axis(column)
        .reset_index(name="records")
    )


def plot_top_counts(
    data: pd.DataFrame, specs: list[tuple[str, int, str]], cols: int = 2
) -> None:
    rows = -(-len(specs) // cols)
    fig, axes = plt.subplots(rows, cols, figsize=(8 * cols, 4.8 * rows), squeeze=False)
    for axis, (column, n, title) in zip(axes.ravel(), specs):
        counts = top_counts(data, column, n=n)
        sns.barplot(data=counts, y=column, x="records", ax=axis, color="#4C78A8")
        axis.set_title(title)
        axis.set_xlabel("Records")
        axis.set_ylabel("")
    for axis in axes.ravel()[len(specs) :]:
        axis.set_visible(False)
    plt.tight_layout()


def date_coverage(data: pd.DataFrame, columns: list[str]) -> pd.DataFrame:
    return pd.DataFrame(
        {
            "date_column": columns,
            "min_date": [data[column].min() for column in columns],
            "max_date": [data[column].max() for column in columns],
            "missing": [data[column].isna().sum() for column in columns],
            "missing_pct": [
                round(data[column].isna().mean() * 100, 1) for column in columns
            ],
        }
    )


def monthly_counts(
    data: pd.DataFrame, date_column: str, label: str = "records"
) -> pd.DataFrame:
    return (
        data.dropna(subset=[date_column])
        .assign(
            month=lambda frame: frame[date_column].dt.to_period("M").dt.to_timestamp()
        )
        .groupby("month")
        .size()
        .rename(label)
        .reset_index()
    )


def monthly_counts_by_category(
    data: pd.DataFrame,
    date_column: str,
    category_column: str,
    top_n: int = 6,
    label: str = "records",
) -> pd.DataFrame:
    top_values = top_counts(data, category_column, n=top_n)[category_column]
    return (
        data[data[category_column].isin(top_values)]
        .dropna(subset=[date_column])
        .assign(
            month=lambda frame: frame[date_column].dt.to_period("M").dt.to_timestamp()
        )
        .groupby(["month", category_column])
        .size()
        .rename(label)
        .reset_index()
    )


def country_disease_matrix(
    data: pd.DataFrame,
    country_column: str,
    disease_column: str,
    country_n: int = 12,
    disease_n: int = 8,
) -> pd.DataFrame:
    top_countries = top_counts(data, country_column, n=country_n)[country_column]
    top_diseases = top_counts(data, disease_column, n=disease_n)[disease_column]
    filtered = data[
        data[country_column].isin(top_countries)
        & data[disease_column].isin(top_diseases)
    ]
    return pd.crosstab(filtered[country_column], filtered[disease_column])

import contextily as cx
import geopandas as gpd

BASEMAP_SOURCE = cx.providers.CartoDB.Positron


def plot_event_map(
    data: pd.DataFrame,
    longitude_column: str,
    latitude_column: str,
    color_column: str,
    title: str,
    sample_n: int | None = None,
    marker_size: float = 18,
    alpha: float = 0.65,
) -> gpd.GeoDataFrame:
    geo_data = data.dropna(subset=[longitude_column, latitude_column]).copy()
    if sample_n is not None and len(geo_data) > sample_n:
        geo_data = geo_data.sample(sample_n, random_state=42)

    gdf = gpd.GeoDataFrame(
        geo_data,
        geometry=gpd.points_from_xy(geo_data[longitude_column], geo_data[latitude_column]),
        crs='EPSG:4326',
    ).to_crs(epsg=3857)

    fig, axis = plt.subplots(figsize=(11, 9))
    gdf.plot(
        ax=axis,
        column=color_column,
        categorical=True,
        legend=True,
        markersize=marker_size,
        alpha=alpha,
        linewidth=0,
    )
    cx.add_basemap(axis, source=BASEMAP_SOURCE, attribution_size=7)
    axis.set_title(title)
    axis.set_axis_off()
    plt.tight_layout()
    return gdf

# %% [markdown]
# ## Load Data
#
# ADIS uses semicolon-delimited CSV exports, decimal commas for numeric fields, and ISO-style dates.

# %%
DATA_PATH = find_data_path(
    "../data/structured/adis/adis-outbreaks-20260519.csv",
    "data/structured/adis/adis-outbreaks-20260519.csv",
)

raw_df = pd.read_csv(
    DATA_PATH,
    sep=";",
    decimal=",",
    na_values=NA_VALUES,
    keep_default_na=True,
    low_memory=False,
)

print(f"Loaded {len(raw_df):,} rows and {raw_df.shape[1]:,} columns from {DATA_PATH}")
raw_df.head()
# Out:
# Loaded 1,423 rows and 46 columns from ../data/structured/adis/adis-outbreaks-20260519.csv
#                    Reference   National reference Country/Territory  \
# 0          IT-SHB-2025-xghqg  SHB_2025_0016-zutgb           Italien
# 1  DE-HPAI(NON-P)-2026-xsyaz         26-015-a0jke       Deutschland
# 2  DE-HPAI(NON-P)-2026-yy25e         26-015-mqw20       Deutschland
# 3  IS-HPAI(NON-P)-2026-xvb7r             WB-r4a6d            Island
# 4  IS-HPAI(NON-P)-2026-65set             WB-nvcax            Island
#
#          Typ                                       Disease name Disease type  \
# 0  Secondary  Aethina tumida (Inf. with)(Small hive beetle)(...          NaN
# 1    Primary                          HPAI(NON-P) in Wild Birds         H5N1
# 2    Primary                          HPAI(NON-P) in Wild Birds         H5N1
# 3    Primary                          HPAI(NON-P) in Wild Birds         H5N1
# 4    Primary                          HPAI(NON-P) in Wild Birds         H5N1
#
#   Epidemiological unit Submitted on Modified on  \
# 0               Apiary   2026-05-13  2026-05-13
# 1       Not applicable   2026-05-19  2026-05-19
# 2       Not applicable   2026-04-20  2026-04-20
# 3       Not applicable   2026-05-05  2026-05-05
# 4       Not applicable   2026-05-06  2026-05-06
#
#   Administrative division level 1 Administrative division level 2  \
# 0                          Sicily                         Messina
# 1             Nordrhein-Westfalen               Ennepe-Ruhr-Kreis
# 2                          Hessen              Hersfeld-Rotenburg
# 3                Höfuðborgarsvæði                       Reykjavík
# 4                Höfuðborgarsvæði                       Reykjavík
#
#   Administrative division level 3  \
# 0                         Messina
# 1                          Witten
# 2                Heringen (Werra)
# 3                             NaN
# 4                             NaN
#
#   Outbreak occurring inside an already restricted zone   Latitude  Longitude  \
# 0                                                NaN    38.209307  15.521267
# 1                                               True    51.410000   7.350000
# 2                                               True    50.910000  10.010000
# 3                                              False    64.139686 -21.964240
# 4                                              False    64.155561 -21.962850
#
#   Approximate location          Location Wildlife type 1 Production Type 1  \
# 0                False           Messina             NaN               NaN
# 1                 True            Witten            Wild               NaN
# 2                 True  Heringen (Werra)            Wild               NaN
# 3                False         Reykjavík            Wild               NaN
# 4                False         Reykjavík            Wild               NaN
#
#    Water type 1 Production system 1 Measuring unit 1  Susceptible 1  Cases 1  \
# 0           NaN                 NaN            Hives            1.0      1.0
# 1           NaN                 NaN            Tiere            NaN      1.0
# 2           NaN                 NaN            Tiere            NaN      1.0
# 3           NaN                 NaN            Tiere            NaN      1.0
# 4           NaN                 NaN            Tiere            NaN      1.0
#
#    Dead 1  Killed 1  Slaughtered 1  Vaccinated 1  Outbreak year  \
# 0     0.0       0.0            NaN           NaN           2025
# 1     1.0       0.0            0.0           0.0           2026
# 2     1.0       0.0            0.0           0.0           2026
# 3     1.0       0.0            0.0           0.0           2026
# 4     1.0       NaN            NaN           NaN           2026
#
#   Suspicion/Start date Confirmation date    End date  \
# 0           2025-12-10        2025-12-24         NaN
# 1           2026-01-27        2026-01-30  2026-01-30
# 2           2026-01-19        2026-02-02  2026-04-17
# 3           2026-02-06        2026-02-16         NaN
# 4           2026-02-02        2026-02-24         NaN
#
#   Status Continuing/Resolved  Suspicion  Clinical signs  Diagnostic tests  \
# 0                 Continuing      False            True              True
# 1                   Resolved      False           False              True
# 2                   Resolved      False           False              True
# 3                 Continuing      False            True              True
# 4                 Continuing      False            True              True
#
#    Necropsy                                         Category 1  \
# 0     False  Other (other than pathogen or antibody detection)
# 1     False                                 Pathogen detection
# 2     False                                 Pathogen detection
# 3     False                                 Pathogen detection
# 4     False                                 Pathogen detection
#
#                                        Subcategory 1  \
# 0  Other (tests other than pathogen or antibody d...
# 1                             Nucleic acid detection
# 2                             Nucleic acid detection
# 3                             Nucleic acid detection
# 4                             Nucleic acid detection
#
#                                          Test name 1 Test type 1  \
# 0                       Morphological identification  Laboratory
# 1  Real-time polymerase chain reaction (real-time...  Laboratory
# 2                    Polymerase chain reaction (PCR)  Laboratory
# 3                    Polymerase chain reaction (PCR)  Laboratory
# 4                    Polymerase chain reaction (PCR)  Laboratory
#
#                Laboratory type 1                 Species 1 Result date 1  \
# 0  National Reference Laboratory                      Bees    2025-12-24
# 1             Private Laboratory               Anser anser    2026-01-30
# 2             Private Laboratory  Anserinae (unidentified)    2026-01-31
# 3  National Reference Laboratory               Anser anser    2026-02-16
# 4  National Reference Laboratory               Anser anser    2026-02-24
#
#   Result type 1   Pertinence
# 0      Positive  EU and WOAH
# 1      Positive  EU and WOAH
# 2      Positive  EU and WOAH
# 3      Positive  EU and WOAH
# 4      Positive  EU and WOAH

# %% [markdown]
# ## Clean Working Copy
#
# Parse dates, numeric burden fields, boolean-like flags, filter to HPAI records, and add derived delay/burden metrics.

# %%
df = raw_df.copy()
df.columns = df.columns.str.strip()

HPAI_MATCH_COLUMNS = ["Disease name", "Disease type"]
hpai_mask = pd.Series(False, index=df.index)
for column in HPAI_MATCH_COLUMNS:
    hpai_mask |= (
        df[column]
        .fillna("")
        .str.contains(
            "HPAI|high pathogenic|high pathogenicity avian influenza",
            case=False,
            regex=True,
        )
    )

df = df.loc[hpai_mask].copy()
print(f"Filtered to {len(df):,} HPAI records from {len(raw_df):,} total ADIS records.")

DATE_COLUMNS = [
    "Submitted on",
    "Modified on",
    "Suspicion/Start date",
    "Confirmation date",
    "End date",
    "Result date 1",
]
for column in DATE_COLUMNS:
    if column in df.columns:
        df[column] = pd.to_datetime(df[column], errors="coerce")

NUMERIC_COLUMNS = [
    "Latitude",
    "Longitude",
    "Susceptible 1",
    "Cases 1",
    "Dead 1",
    "Killed 1",
    "Slaughtered 1",
    "Vaccinated 1",
    "Outbreak year",
]
for column in NUMERIC_COLUMNS:
    if column in df.columns:
        df[column] = pd.to_numeric(df[column], errors="coerce")

BOOLEAN_LIKE_COLUMNS = [
    "Outbreak occurring inside an already restricted zone",
    "Approximate location",
    "Suspicion",
    "Clinical signs",
    "Diagnostic tests",
    "Necropsy",
]
for column in BOOLEAN_LIKE_COLUMNS:
    if column in df.columns:
        df[column] = df[column].map({"true": True, "false": False})

df["confirmation_delay_days"] = (
    df["Confirmation date"] - df["Suspicion/Start date"]
).dt.days
df["submission_delay_days"] = (df["Submitted on"] - df["Confirmation date"]).dt.days
df["outbreak_duration_days"] = (df["End date"] - df["Suspicion/Start date"]).dt.days
df["total_affected_or_removed"] = df[
    ["Cases 1", "Dead 1", "Killed 1", "Slaughtered 1"]
].sum(axis=1, min_count=1)

duplicate_summary = pd.Series(
    {
        "duplicate_reference": df["Reference"].duplicated().sum(),
        "duplicate_national_reference": df["National reference"].duplicated().sum(),
    }
)

display(df.dtypes.to_frame("dtype"))
display(duplicate_summary.to_frame("count"))
# Out:
# Filtered to 204 HPAI records from 1,423 total ADIS records.
#                                                              dtype
# Reference                                                      str
# National reference                                             str
# Country/Territory                                              str
# Typ                                                            str
# Disease name                                                   str
# Disease type                                                   str
# Epidemiological unit                                           str
# Submitted on                                        datetime64[us]
# Modified on                                         datetime64[us]
# Administrative division level 1                                str
# Administrative division level 2                                str
# Administrative division level 3                                str
# Outbreak occurring inside an already restricted...          object
# Latitude                                                   float64
# Longitude                                                  float64
# Approximate location                                        object
# Location                                                       str
# Wildlife type 1                                                str
# Production Type 1                                              str
# Water type 1                                               float64
# Production system 1                                            str
# Measuring unit 1                                               str
# Susceptible 1                                              float64
# Cases 1                                                    float64
# Dead 1                                                     float64
# Killed 1                                                   float64
# Slaughtered 1                                              float64
# Vaccinated 1                                               float64
# Outbreak year                                                int64
# Suspicion/Start date                                datetime64[us]
# Confirmation date                                   datetime64[us]
# End date                                            datetime64[us]
# Status Continuing/Resolved                                     str
# Suspicion                                                   object
# Clinical signs                                              object
# Diagnostic tests                                            object
# Necropsy                                                    object
# Category 1                                                     str
# Subcategory 1                                                  str
# Test name 1                                                    str
# Test type 1                                                    str
# Laboratory type 1                                              str
# Species 1                                                      str
# Result date 1                                       datetime64[us]
# Result type 1                                                  str
# Pertinence                                                     str
# confirmation_delay_days                                      int64
# submission_delay_days                                        int64
# outbreak_duration_days                                     float64
# total_affected_or_removed                                  float64
#                               count
# duplicate_reference               0
# duplicate_national_reference     12

# %% [markdown]
# ## Dataset Overview And Completeness

# %%
overview = pd.DataFrame(
    {
        "rows": [len(df)],
        "columns": [df.shape[1]],
        "countries": [df["Country/Territory"].nunique()],
        "diseases": [df["Disease name"].nunique()],
        "species": [df["Species 1"].nunique()],
        "continuing_statuses": [df["Status Continuing/Resolved"].nunique()],
        "first_suspicion_date": [df["Suspicion/Start date"].min()],
        "last_suspicion_date": [df["Suspicion/Start date"].max()],
    }
)

display(overview)
display(schema_summary(df).head(35))
display(date_coverage(df, [column for column in DATE_COLUMNS if column in df.columns]))
# Out:
#    rows  columns  countries  diseases  species  continuing_statuses  \
# 0   204       50         16         3       31                    2
#
#   first_suspicion_date last_suspicion_date
# 0           2026-01-19          2026-05-16
#                                                              dtype  missing  \
# Outbreak occurring inside an already restricted...          object      204
# Approximate location                                        object      204
# Water type 1                                               float64      204
# Production system 1                                            str      204
# Suspicion                                                   object      204
# Clinical signs                                              object      204
# Diagnostic tests                                            object      204
# Necropsy                                                    object      204
# Susceptible 1                                              float64      139
# Production Type 1                                              str      139
# Vaccinated 1                                               float64      114
# Slaughtered 1                                              float64      113
# Killed 1                                                   float64       65
# End date                                            datetime64[us]       65
# outbreak_duration_days                                     float64       65
# Wildlife type 1                                                str       65
# Administrative division level 3                                str       35
# National reference                                             str       13
# Administrative division level 2                                str        7
# Result date 1                                       datetime64[us]        6
# Species 1                                                      str        6
# Test name 1                                                    str        6
# Laboratory type 1                                              str        6
# Subcategory 1                                                  str        6
# Category 1                                                     str        6
# Test type 1                                                    str        6
# Result type 1                                                  str        6
# Cases 1                                                    float64        5
# Dead 1                                                     float64        2
# Reference                                                      str        0
# Longitude                                                  float64        0
# Latitude                                                   float64        0
# Location                                                       str        0
# total_affected_or_removed                                  float64        0
# Suspicion/Start date                                datetime64[us]        0
#
#                                                     missing_pct  n_unique
# Outbreak occurring inside an already restricted...        100.0         0
# Approximate location                                      100.0         0
# Water type 1                                              100.0         0
# Production system 1                                       100.0         0
# Suspicion                                                 100.0         0
# Clinical signs                                            100.0         0
# Diagnostic tests                                          100.0         0
# Necropsy                                                  100.0         0
# Susceptible 1                                              68.1        64
# Production Type 1                                          68.1         2
# Vaccinated 1                                               55.9         1
# Slaughtered 1                                              55.4         1
# Killed 1                                                   31.9        54
# End date                                                   31.9        39
# outbreak_duration_days                                     31.9        28
# Wildlife type 1                                            31.9         1
# Administrative division level 3                            17.2        99
# National reference                                          6.4       191
# Administrative division level 2                             3.4       101
# Result date 1                                               2.9        46
# Species 1                                                   2.9        31
# Test name 1                                                 2.9         5
# Laboratory type 1                                           2.9         4
# Subcategory 1                                               2.9         2
# Category 1                                                  2.9         1
# Test type 1                                                 2.9         1
# Result type 1                                               2.9         1
# Cases 1                                                     2.5        65
# Dead 1                                                      1.0        53
# Reference                                                   0.0       204
# Longitude                                                   0.0       189
# Latitude                                                    0.0       180
# Location                                                    0.0       158
# total_affected_or_removed                                   0.0        70
# Suspicion/Start date                                        0.0        63
#             date_column   min_date   max_date  missing  missing_pct
# 0          Submitted on 2026-04-20 2026-05-19        0          0.0
# 1           Modified on 2026-04-20 2026-05-19        0          0.0
# 2  Suspicion/Start date 2026-01-19 2026-05-16        0          0.0
# 3     Confirmation date 2026-01-30 2026-05-19        0          0.0
# 4              End date 2026-01-30 2026-05-19       65         31.9
# 5         Result date 1 2026-01-30 2026-05-19        6          2.9

# %% [markdown]
# ## Top Categories

# %%
CATEGORY_COLUMNS = [
    "Country/Territory",
    "Disease name",
    "Disease type",
    "Species 1",
    "Status Continuing/Resolved",
    "Epidemiological unit",
]

for column in CATEGORY_COLUMNS:
    display(top_counts(df, column, n=20))
# Out:
#         Country/Territory  records
# 0             Deutschland       84
# 1                   Polen       65
# 2              Österreich       11
# 3                Norwegen        8
# 4              Frankreich        6
# 5             Niederlande        6
# 6                Dänemark        6
# 7                  Island        4
# 8                Finnland        4
# 9                 Estland        2
# 10                Belgien        2
# 11  Tschechische Republik        2
# 12           Griechenland        1
# 13                Italien        1
# 14                Ukraine        1
# 15               Schweden        1
#                                         Disease name  records
# 0                          HPAI(NON-P) in Wild Birds      139
# 1  High pathogenicity avian influenza viruses (In...       58
# 2                       HPAI(NON-P) in Captive Birds        7
#   Disease type  records
# 0         H5N1      202
# 1         H5N5        2
#                         Species 1  records
# 0                           Birds       64
# 1                     Anser anser       49
# 2                     Cygnus olor       22
# 3                     Buteo buteo        7
# 4        Accipitridae (incognita)        6
# 5                         Missing        6
# 6                Branta leucopsis        6
# 7               Branta canadensis        5
# 8            Anatidae (incognita)        4
# 9                 Ciconia ciconia        4
# 10       Anserinae (unidentified)        3
# 11                Branta bernicla        3
# 12               Rissa tridactyla        2
# 13  Phalacrocoracidae (incognita)        2
# 14             Accipiter gentilis        2
# 15               Larus argentatus        2
# 16                Corvus monedula        2
# 17                   Corvus corax        1
# 18               Larus cachinnans        1
# 19                  Cygnus cygnus        1
#   Status Continuing/Resolved  records
# 0                   Resolved      139
# 1                 Continuing       65
#   Epidemiological unit  records
# 0       Not applicable      104
# 1                 Farm       58
# 2                Other       32
# 3             Backyard        6
# 4        Body of water        2
# 5         Natural park        2

# %%
plot_top_counts(
    df,
    [
        ("Country/Territory", 15, "Top Countries/Territories"),
        ("Disease name", 12, "Top Diseases"),
        ("Species 1", 12, "Top Species"),
        ("Status Continuing/Resolved", 8, "Outbreak Status"),
    ],
)

# %% [markdown]
# ## Time Coverage And Trends

# %%
events_by_month = monthly_counts(df, "Suspicion/Start date", label="outbreak_records")

sns.lineplot(data=events_by_month, x="month", y="outbreak_records", marker="o")
plt.title("ADIS Records By Suspicion/Start Month")
plt.xlabel("Suspicion/start month")
plt.ylabel("Outbreak records")
plt.xticks(rotation=45)
plt.tight_layout()

# %%
events_by_month_and_disease = monthly_counts_by_category(
    df,
    date_column="Suspicion/Start date",
    category_column="Disease name",
    top_n=6,
    label="outbreak_records",
)

sns.lineplot(
    data=events_by_month_and_disease,
    x="month",
    y="outbreak_records",
    hue="Disease name",
    marker="o",
)
plt.title("Top ADIS Diseases Over Time")
plt.xlabel("Suspicion/start month")
plt.ylabel("Outbreak records")
plt.xticks(rotation=45)
plt.legend(title="Disease", bbox_to_anchor=(1.02, 1), loc="upper left")
plt.tight_layout()

# %% [markdown]
# ## Delay Analysis

# %%
delay_columns = [
    "confirmation_delay_days",
    "submission_delay_days",
    "outbreak_duration_days",
]

display(df[delay_columns].describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9, 0.95]).T)

fig, axes = plt.subplots(1, len(delay_columns), figsize=(5.4 * len(delay_columns), 4.2))
for axis, column in zip(axes, delay_columns):
    values = df[column].dropna()
    if not values.empty:
        values = values[
            (values >= values.quantile(0.01)) & (values <= values.quantile(0.99))
        ]
    sns.histplot(values, bins=30, ax=axis)
    axis.set_title(column.replace("_", " ").title())
    axis.set_xlabel("Days")
plt.tight_layout()
# Out:
#                          count       mean        std  min  10%  25%  50%  \
# confirmation_delay_days  204.0   9.235294  12.561711  0.0  1.0  1.0  7.0
# submission_delay_days    204.0   7.401961  14.670946  0.0  1.0  1.0  3.0
# outbreak_duration_days   139.0  10.791367  12.923114  0.0  2.0  4.5  8.0
#
#                           75%   90%   95%    max
# confirmation_delay_days  12.0  18.7  22.0  112.0
# submission_delay_days     6.0  15.7  32.0  109.0
# outbreak_duration_days   14.0  21.2  23.4  112.0

# %%
df.loc[
    df[delay_columns].notna().any(axis=1),
    [
        "Country/Territory",
        "Disease name",
        "Suspicion/Start date",
        "Confirmation date",
        "Submitted on",
        *delay_columns,
    ],
].sort_values("confirmation_delay_days", ascending=False).head(20)
# Out:
#      Country/Territory               Disease name Suspicion/Start date  \
# 1201           Belgien  HPAI(NON-P) in Wild Birds           2026-01-19
# 845           Dänemark  HPAI(NON-P) in Wild Birds           2026-02-18
# 846           Dänemark  HPAI(NON-P) in Wild Birds           2026-02-24
# 639           Schweden  HPAI(NON-P) in Wild Birds           2026-03-03
# 203         Frankreich  HPAI(NON-P) in Wild Birds           2026-03-06
# 1312       Niederlande  HPAI(NON-P) in Wild Birds           2026-04-01
# 847           Dänemark  HPAI(NON-P) in Wild Birds           2026-03-25
# 5          Deutschland  HPAI(NON-P) in Wild Birds           2026-02-02
# 606        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-01
# 433        Deutschland  HPAI(NON-P) in Wild Birds           2026-03-31
# 558           Dänemark  HPAI(NON-P) in Wild Birds           2026-04-05
# 698        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-07
# 697        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-07
# 701        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-07
# 699        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-07
# 700        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-07
# 4               Island  HPAI(NON-P) in Wild Birds           2026-02-02
# 462        Deutschland  HPAI(NON-P) in Wild Birds           2026-04-02
# 41         Deutschland  HPAI(NON-P) in Wild Birds           2026-03-19
# 37         Deutschland  HPAI(NON-P) in Wild Birds           2026-03-18
#
#      Confirmation date Submitted on  confirmation_delay_days  \
# 1201        2026-05-11   2026-05-12                      112
# 845         2026-05-01   2026-05-08                       72
# 846         2026-05-01   2026-05-08                       66
# 639         2026-04-28   2026-04-30                       56
# 203         2026-04-20   2026-04-22                       45
# 1312        2026-05-13   2026-05-16                       42
# 847         2026-05-01   2026-05-08                       37
# 5           2026-03-04   2026-05-07                       30
# 606         2026-04-28   2026-05-07                       27
# 433         2026-04-23   2026-04-28                       23
# 558         2026-04-27   2026-04-30                       22
# 698         2026-04-29   2026-05-06                       22
# 697         2026-04-29   2026-05-06                       22
# 701         2026-04-29   2026-05-06                       22
# 699         2026-04-29   2026-05-06                       22
# 700         2026-04-29   2026-05-06                       22
# 4           2026-02-24   2026-05-06                       22
# 462         2026-04-23   2026-04-27                       21
# 41          2026-04-09   2026-04-23                       21
# 37          2026-04-07   2026-04-23                       20
#
#       submission_delay_days  outbreak_duration_days
# 1201                      1                   112.0
# 845                       7                     0.0
# 846                       7                     0.0
# 639                       2                     0.0
# 203                       2                     NaN
# 1312                      3                     NaN
# 847                       7                     0.0
# 5                        64                     8.0
# 606                       9                    27.0
# 433                       5                    23.0
# 558                       3                     0.0
# 698                       7                    22.0
# 697                       7                    22.0
# 701                       7                    22.0
# 699                       7                    22.0
# 700                       7                    22.0
# 4                        71                     NaN
# 462                       4                    22.0
# 41                       14                    21.0
# 37                       16                    20.0

# %% [markdown]
# ## Country-Disease Matrix

# %%
matrix = country_disease_matrix(df, "Country/Territory", "Disease name")

sns.heatmap(matrix, annot=True, fmt="d", cmap="YlGnBu")
plt.title("Top ADIS Countries/Territories And Diseases")
plt.xlabel("Disease")
plt.ylabel("Country/Territory")
plt.tight_layout()

# %% [markdown]
# ## Geographic Snapshot
#
# Map HPAI outbreak coordinates on a basemap. This cell uses `contextily` basemap tiles when executed; set `BASEMAP_SOURCE` in the setup cell if another provider is preferred.

# %%
geo_df = df.dropna(subset=['Longitude', 'Latitude']).copy()

display(geo_df[['Longitude', 'Latitude']].describe())

mapped_events = plot_event_map(
    geo_df,
    longitude_column='Longitude',
    latitude_column='Latitude',
    color_column='Disease name',
    title='ADIS HPAI Outbreak Coordinates',
    marker_size=28,
    alpha=0.75,
)

mapped_events[['Country/Territory', 'Disease name', 'Disease type', 'Latitude', 'Longitude']].head()
# Out:
#         Longitude    Latitude
# count  204.000000  204.000000
# mean    13.022535   53.001261
# std      7.639079    4.196203
# min    -22.565944   40.508903
# 25%      9.082500   51.602500
# 50%     12.398658   52.702266
# 75%     19.516230   53.580000
# max     30.045100   69.601000
#   Country/Territory               Disease name Disease type   Latitude  \
# 1       Deutschland  HPAI(NON-P) in Wild Birds         H5N1  51.410000
# 2       Deutschland  HPAI(NON-P) in Wild Birds         H5N1  50.910000
# 3            Island  HPAI(NON-P) in Wild Birds         H5N1  64.139686
# 4            Island  HPAI(NON-P) in Wild Birds         H5N1  64.155561
# 5       Deutschland  HPAI(NON-P) in Wild Birds         H5N1  51.610000
#
#    Longitude
# 1    7.35000
# 2   10.01000
# 3  -21.96424
# 4  -21.96285
# 5    7.50000

# %% [markdown]
# ## Source-Specific Signals
#
# ADIS includes outbreak burden, continuing/resolved status, diagnostic evidence, and administrative divisions.

# %%
burden_columns = [
    "Susceptible 1",
    "Cases 1",
    "Dead 1",
    "Killed 1",
    "Slaughtered 1",
    "Vaccinated 1",
    "total_affected_or_removed",
]

display(df[burden_columns].describe(percentiles=[0.5, 0.75, 0.9, 0.95, 0.99]).T)

source_specific = {
    "continuing_by_country": pd.crosstab(
        df["Country/Territory"], df["Status Continuing/Resolved"], dropna=False
    ).sort_index(),
    "diagnostics_by_disease": pd.crosstab(
        df["Disease name"], df["Diagnostic tests"], dropna=False
    ),
    "top_admin1": top_counts(df, "Administrative division level 1", 20),
    "restricted_zone_by_disease": pd.crosstab(
        df["Disease name"],
        df["Outbreak occurring inside an already restricted zone"],
        dropna=False,
    ),
}

display(source_specific["continuing_by_country"].tail(20))
display(source_specific["diagnostics_by_disease"].head(20))
display(source_specific["top_admin1"])
display(source_specific["restricted_zone_by_disease"].head(20))
# Out:
#                            count          mean            std  min      50%  \
# Susceptible 1               65.0  52794.707692  125922.729608  8.0  19271.0
# Cases 1                    199.0  16899.236181   75756.748898  1.0      1.0
# Dead 1                     202.0    213.470297    1847.038536  0.0      1.0
# Killed 1                   139.0  22049.424460   89710.114099  0.0      0.0
# Slaughtered 1               91.0      0.000000       0.000000  0.0      0.0
# Vaccinated 1                90.0      0.000000       0.000000  0.0      0.0
# total_affected_or_removed  204.0  31720.289216  149303.715750  1.0      2.0
#
#                                 75%      90%       95%        99%        max
# Susceptible 1              41237.00  86457.0  257035.0  679478.96   707726.0
# Cases 1                     4246.00  30221.2   58964.5  312642.20   707726.0
# Dead 1                        19.75    300.0     595.0    1268.31    26100.0
# Killed 1                    5959.00  35879.0   84306.2  527191.60   707346.0
# Slaughtered 1                  0.00      0.0       0.0       0.00        0.0
# Vaccinated 1                   0.00      0.0       0.0       0.00        0.0
# total_affected_or_removed   6815.25  49550.8   91992.3  610339.90  1415452.0
# Status Continuing/Resolved  Continuing  Resolved
# Country/Territory
# Belgien                              0         2
# Deutschland                          6        78
# Dänemark                             0         6
# Estland                              1         1
# Finnland                             0         4
# Frankreich                           5         1
# Griechenland                         0         1
# Island                               2         2
# Italien                              0         1
# Niederlande                          6         0
# Norwegen                             0         8
# Polen                               42        23
# Schweden                             0         1
# Tschechische Republik                2         0
# Ukraine                              1         0
# Österreich                           0        11
# Diagnostic tests                                    NaN
# Disease name
# HPAI(NON-P) in Captive Birds                          7
# HPAI(NON-P) in Wild Birds                           139
# High pathogenicity avian influenza viruses (Inf...   58
#      Administrative division level 1  records
# 0                        Mazowieckie       31
# 1                Nordrhein-Westfalen       22
# 2                            Hamburg       20
# 3                 Schleswig-Holstein       12
# 4                      Wielkopolskie       11
# 5                      Niedersachsen       10
# 6                             Bayern       10
# 7                Warmińsko-Mazurskie        8
# 8                               Wien        8
# 9                          Lubelskie        6
# 10                          Nordland        5
# 11   Veterinary Inspection Unit East        5
# 12                Kujawsko-Pomorskie        4
# 13                            Hessen        3
# 14  Etelä-Suomen aluehallintovirasto        3
# 15                  Niederösterreich        3
# 16                  Höfuðborgarsvæði        2
# 17                          Suðurnes        2
# 18                      Zuid-Holland        2
# 19                          Wallonie        2
# Outbreak occurring inside an already restricted zone  NaN
# Disease name
# HPAI(NON-P) in Captive Birds                            7
# HPAI(NON-P) in Wild Birds                             139
# High pathogenicity avian influenza viruses (Inf...     58

# %% [markdown]
# ## Quick Filters
#
# Set any filter to a string value, or leave it as `None` to ignore that filter.

# %%
country_filter = None
disease_filter = None
status_filter = None
species_filter = None

filtered = df.copy()
if country_filter:
    filtered = filtered[filtered["Country/Territory"].eq(country_filter)]
if disease_filter:
    filtered = filtered[filtered["Disease name"].eq(disease_filter)]
if status_filter:
    filtered = filtered[filtered["Status Continuing/Resolved"].eq(status_filter)]
if species_filter:
    filtered = filtered[filtered["Species 1"].eq(species_filter)]

filtered.sort_values("Submitted on", ascending=False).head(50)
# Out:
#                       Reference National reference      Country/Territory  \
# 1     DE-HPAI(NON-P)-2026-xsyaz       26-015-a0jke            Deutschland
# 851   DE-HPAI(NON-P)-2026-nbc5q       26-015-4zpqr            Deutschland
# 1407  PL-HPAI(NON-P)-2026-pntkm     2026/16c-5nw1y                  Polen
# 1295  DE-HPAI(NON-P)-2026-8fv4x       26-015-azdy8            Deutschland
# 1294  DE-HPAI(NON-P)-2026-54n9n       26-015-smwte            Deutschland
# 1293  DE-HPAI(NON-P)-2026-364i1       26-015-k9h21            Deutschland
# 1292  DE-HPAI(NON-P)-2026-nqg4e       26-015-0ihz6            Deutschland
# 1291  DE-HPAI(NON-P)-2026-0xjvs       26-015-4omc3            Deutschland
# 1290  DE-HPAI(NON-P)-2026-51nvr       26-015-iru1a            Deutschland
# 1289  DE-HPAI(NON-P)-2026-shvom       26-015-jiv02            Deutschland
# 1041  DE-HPAI(NON-P)-2026-parwo       26-015-v92z4            Deutschland
# 1422  NO-HPAI(NON-P)-2026-zpxa4      2026-07-9tlfx               Norwegen
# 1299  PL-HPAI(NON-P)-2026-wpa1j     2026/223-exsih                  Polen
# 1053           2026           2026-05-05        2026-05-07        NaT
# 1158           2026           2026-05-07        2026-05-08        NaT
# 1071           2026           2026-05-06        2026-05-07 2026-05-07
# 846            2026           2026-02-24        2026-05-01 2026-02-24
# 847            2026           2026-03-25        2026-05-01 2026-03-25
# 1159           2026           2026-05-04        2026-05-08 2026-05-08
# 845            2026           2026-02-18        2026-05-01 2026-02-18
# 1074           2026           2026-05-06        2026-05-07        NaT
# 870            2026           2026-04-22        2026-05-04 2026-05-04
# 869            2026           2026-04-15        2026-05-04 2026-05-04
# 990            2026           2026-05-05        2026-05-06        NaT
# 991            2026           2026-05-05        2026-05-06        NaT
# 422            2026           2026-04-17        2026-04-23        NaT
# 1092           2026           2026-05-04        2026-05-07        NaT
#
#      Status Continuing/Resolved Suspicion Clinical signs Diagnostic tests  \
# 1                      Resolved       NaN            NaN              NaN
# 851                    Resolved       NaN            NaN              NaN
# 1407                 Continuing       NaN            NaN              NaN
# 1295                   Resolved       NaN            NaN              NaN
# 1294                   Resolved       NaN            NaN              NaN
# 1293                   Resolved       NaN            NaN              NaN
# 1292                   Resolved       NaN            NaN              NaN
# 1291                   Resolved       NaN            NaN              NaN
# 1290                   Resolved       NaN            NaN              NaN
# 1289                   Resolved       NaN            NaN              NaN
# 1041                   Resolved       NaN            NaN              NaN
# 1422                   Resolved       NaN            NaN              NaN
# 1299                   Resolved       NaN            NaN              NaN
# 1412                   Resolved       NaN            NaN              NaN
# 1388                 Continuing       NaN            NaN              NaN
# 1108                   Resolved       NaN            NaN              NaN
# 1390                   Resolved       NaN            NaN              NaN
# 1348                 Continuing       NaN            NaN              NaN
# 1312                 Continuing       NaN            NaN              NaN
# 1392                 Continuing       NaN            NaN              NaN
# 1391                 Continuing       NaN            NaN              NaN
# 1352                 Continuing       NaN            NaN              NaN
# 1313                   Resolved       NaN            NaN              NaN
# 1319                   Resolved       NaN            NaN              NaN
# 1323                 Continuing       NaN            NaN              NaN
# 1322                 Continuing       NaN            NaN              NaN
# 1318                   Resolved       NaN            NaN              NaN
# 1259                 Continuing       NaN            NaN              NaN
# 1255                 Continuing       NaN            NaN              NaN
# 1191                 Continuing       NaN            NaN              NaN
# 1190                 Continuing       NaN            NaN              NaN
# 1201                   Resolved       NaN            NaN              NaN
# 1171                 Continuing       NaN            NaN              NaN
# 1173                 Continuing       NaN            NaN              NaN
# 1174                 Continuing       NaN            NaN              NaN
# 1175                 Continuing       NaN            NaN              NaN
# 1053                 Continuing       NaN            NaN              NaN
# 1158                 Continuing       NaN            NaN              NaN
# 1071                   Resolved       NaN            NaN              NaN
# 846                    Resolved       NaN            NaN              NaN
# 847                    Resolved       NaN            NaN              NaN
# 1159                   Resolved       NaN            NaN              NaN
# 845                    Resolved       NaN            NaN              NaN
# 1074                 Continuing       NaN            NaN              NaN
# 870                    Resolved       NaN            NaN              NaN
# 869                    Resolved       NaN            NaN              NaN
# 990                  Continuing       NaN            NaN              NaN
# 991                  Continuing       NaN            NaN              NaN
# 422                  Continuing       NaN            NaN              NaN
# 1092                 Continuing       NaN            NaN              NaN
#
#      Necropsy          Category 1           Subcategory 1  \
# 1         NaN  Pathogen detection  Nucleic acid detection
# 851       NaN  Pathogen detection  Nucleic acid detection
# 1407      NaN  Pathogen detection  Nucleic acid detection
# 1295      NaN  Pathogen detection  Nucleic acid detection
# 1294      NaN  Pathogen detection  Nucleic acid detection
# 1293      NaN  Pathogen detection  Nucleic acid detection
# 1292      NaN  Pathogen detection  Nucleic acid detection
# 1291      NaN  Pathogen detection  Nucleic acid detection
# 1290      NaN  Pathogen detection  Nucleic acid detection
# 1289      NaN  Pathogen detection  Nucleic acid detection
# 1041      NaN  Pathogen detection  Nucleic acid detection
# 1422      NaN  Pathogen detection  Nucleic acid detection
# 1299      NaN  Pathogen detection  Nucleic acid detection
# 1412      NaN  Pathogen detection  Nucleic acid detection
# 1388      NaN  Pathogen detection  Nucleic acid detection
# 1108      NaN  Pathogen detection  Nucleic acid detection
# 1390      NaN  Pathogen detection  Nucleic acid detection
# 1348      NaN                 NaN                     NaN
# 1312      NaN                 NaN                     NaN
# 1392      NaN  Pathogen detection  Nucleic acid detection
# 1391      NaN  Pathogen detection  Nucleic acid detection
# 1352      NaN  Pathogen detection  Nucleic acid detection
# 1313      NaN  Pathogen detection  Nucleic acid detection
# 1319      NaN  Pathogen detection  Nucleic acid detection
# 1323      NaN  Pathogen detection  Nucleic acid detection
# 1322      NaN  Pathogen detection  Nucleic acid detection
# 1318      NaN  Pathogen detection  Nucleic acid detection
# 1259      NaN  Pathogen detection  Nucleic acid detection
# 1255      NaN  Pathogen detection  Nucleic acid detection
# 1191      NaN  Pathogen detection  Nucleic acid detection
# 1190      NaN  Pathogen detection  Nucleic acid detection
# 1201      NaN  Pathogen detection              Genotyping
# 1171      NaN  Pathogen detection  Nucleic acid detection
# 1173      NaN  Pathogen detection  Nucleic acid detection
# 1174      NaN  Pathogen detection  Nucleic acid detection
# 1175      NaN  Pathogen detection  Nucleic acid detection
# 1053      NaN  Pathogen detection  Nucleic acid detection
# 1158      NaN  Pathogen detection  Nucleic acid detection
# 1071      NaN  Pathogen detection  Nucleic acid detection
# 846       NaN  Pathogen detection  Nucleic acid detection
# 847       NaN  Pathogen detection  Nucleic acid detection
# 1159      NaN  Pathogen detection  Nucleic acid detection
# 845       NaN  Pathogen detection  Nucleic acid detection
# 1074      NaN  Pathogen detection  Nucleic acid detection
# 870       NaN  Pathogen detection  Nucleic acid detection
# 869       NaN  Pathogen detection  Nucleic acid detection
# 990       NaN  Pathogen detection  Nucleic acid detection
# 991       NaN  Pathogen detection  Nucleic acid detection
# 422       NaN  Pathogen detection  Nucleic acid detection
# 1092      NaN  Pathogen detection  Nucleic acid detection
#
#                                             Test name 1 Test type 1  \
# 1     Real-time polymerase chain reaction (real-time...  Laboratory
# 851   Real-time polymerase chain reaction (real-time...  Laboratory
# 1407  Real-time reverse transcription polymerase cha...  Laboratory
# 1295                    Polymerase chain reaction (PCR)  Laboratory
# 1294                    Polymerase chain reaction (PCR)  Laboratory
# 1293                    Polymerase chain reaction (PCR)  Laboratory
# 1292                    Polymerase chain reaction (PCR)  Laboratory
# 1291                    Polymerase chain reaction (PCR)  Laboratory
# 1290                    Polymerase chain reaction (PCR)  Laboratory
# 1289                    Polymerase chain reaction (PCR)  Laboratory
# 1041                    Polymerase chain reaction (PCR)  Laboratory
# 1422  Real-time polymerase chain reaction (real-time...  Laboratory
# 1299  Real-time reverse transcription polymerase cha...  Laboratory
# 1412  Reverse transcription-polymerase chain reactio...  Laboratory
# 1388  Real-time reverse transcription polymerase cha...  Laboratory
# 1108  Real-time polymerase chain reaction (real-time...  Laboratory
# 1390  Real-time reverse transcription polymerase cha...  Laboratory
# 1348                                                NaN         NaN
# 1312                                                NaN         NaN
# 1392  Reverse transcription-polymerase chain reactio...  Laboratory
# 1391  Reverse transcription-polymerase chain reactio...  Laboratory
# 1352  Reverse transcription-polymerase chain reactio...  Laboratory
# 1313  Real-time reverse transcription polymerase cha...  Laboratory
# 1319  Real-time reverse transcription polymerase cha...  Laboratory
# 1323  Real-time reverse transcription polymerase cha...  Laboratory
# 1322  Real-time reverse transcription polymerase cha...  Laboratory
# 1318  Real-time reverse transcription polymerase cha...  Laboratory
# 1259  Real-time reverse transcription polymerase cha...  Laboratory
# 1255  Reverse transcription-polymerase chain reactio...  Laboratory
# 1191  Real-time reverse transcription polymerase cha...  Laboratory
# 1190  Reverse transcription-polymerase chain reactio...  Laboratory
# 1201                                    Gene sequencing  Laboratory
# 1171  Real-time reverse transcription polymerase cha...  Laboratory
# 1173  Real-time reverse transcription polymerase cha...  Laboratory
# 1174  Real-time reverse transcription polymerase cha...  Laboratory
# 1175  Real-time reverse transcription polymerase cha...  Laboratory
# 1053  Real-time polymerase chain reaction (real-time...  Laboratory
# 1158  Reverse transcription-polymerase chain reactio...  Laboratory
# 1071  Real-time reverse transcription polymerase cha...  Laboratory
# 846   Real-time polymerase chain reaction (real-time...  Laboratory
# 847   Real-time polymerase chain reaction (real-time...  Laboratory
# 1159  Real-time reverse transcription polymerase cha...  Laboratory
# 845   Real-time polymerase chain reaction (real-time...  Laboratory
# 1074  Real-time reverse transcription polymerase cha...  Laboratory
# 870                     Polymerase chain reaction (PCR)  Laboratory
# 869                     Polymerase chain reaction (PCR)  Laboratory
# 990   Real-time reverse transcription polymerase cha...  Laboratory
# 991   Real-time reverse transcription polymerase cha...  Laboratory
# 422                     Polymerase chain reaction (PCR)  Laboratory
# 1092  Reverse transcription-polymerase chain reactio...  Laboratory
#
#                   Laboratory type 1             Species 1 Result date 1  \
# 1                Private Laboratory           Anser anser    2026-01-30
# 851              Private Laboratory           Anser anser    2026-05-04
# 1407  National Reference Laboratory                 Birds    2026-05-18
# 1295             Private Laboratory       Branta bernicla    2026-05-12
# 1294             Private Laboratory      Branta leucopsis    2026-05-12
# 1293             Private Laboratory       Branta bernicla    2026-05-12
# 1292             Private Laboratory      Branta leucopsis    2026-05-12
# 1291             Private Laboratory           Anser anser    2026-05-12
# 1290             Private Laboratory           Anser anser    2026-05-12
# 1289             Private Laboratory           Anser anser    2026-05-12
